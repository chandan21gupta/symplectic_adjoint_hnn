# %%
import torch
import numpy as np
import torch.nn as nn
from mass_spring import get_dataset
from tqdm import tqdm
from torch.autograd import grad
torch.manual_seed(42)
np.random.seed(42)
from model import *
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
def predict(test_data, model, method, integrator, device, T_test, dt):
    print(integrator)
    dim = 20
    model = model.to(device).to(dtype=torch.float64)
    model.eval()

    z_0_npy = test_data[0, :, :]

    z_0 = torch.from_numpy(z_0_npy).to(device).to(dtype=torch.float64)

    trajectory_predicted = numerically_integrate(integrator=integrator, p_0=z_0[:, :dim], q_0=z_0[:, dim:], model=model, \
        method=method, T=T_test, dt=dt, volatile=True, device=device, coarsening_factor=1).to(torch.float64)

    return trajectory_predicted

# %%
def train(integrator_train = 'euler'):
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu')
    n_samples = 100
    batch_size = 32
    dim = 20
    max_t = 100
    n_epochs = 100
    # integrator_train = integrator_train
    dt = 1
    method = 5
    coarsening_factor = 100
    # data = get_dataset(seed = 42, samples = n_samples, noise = False)
    # x = np.transpose(data['x'], (1, 0, 2))
    # test_x = np.transpose(data['test_x'], (1, 0, 2))
    data = np.load("train_data_chain_newA.npy")[:, :n_samples,:]
    test_data = np.load("test_data_chain_newA.npy")
    # data = x.copy()
    # test_data = test_x.copy()
    mse = nn.MSELoss()
    z_0_npy = data[0, :, :]
    model = MLP2H_Separable_Hamilt(2048, dim)
    model = model.to(device).to(dtype=torch.float64)
    # data = data.to(device)
    # test_data = test_data.to(device)
    # scheduler = ReduceLROnPlateau(opt_model, 'min', patience = scheduler_patience, verbose=True, factor=scheduler_factor)
    params_lst = model.parameters()
    opt_model = torch.optim.Adam(params_lst, lr=0.001)
    loss_record = []
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu')
    for epoch in tqdm(range(n_epochs)):
        total_error = 0
        perm = torch.randperm(n_samples).numpy().tolist()
        data_permed = data[:, perm, :]
        z_0_npy_permed = z_0_npy[perm, :]
        for i in range(0, n_samples, batch_size):
            opt_model.zero_grad()
            if i+batch_size > n_samples:
                break
            batch = data_permed[:max_t, i:(i+batch_size), :]
            z_0_batch_npy = z_0_npy_permed[i:(i+batch_size), :]
            z_0_batch = torch.from_numpy(z_0_batch_npy).to(dtype=torch.float64)
            z_0_batch_device = z_0_batch.to(device)
            p_0 = z_0_batch_device[:, :dim]
            q_0 = z_0_batch_device[:, dim:]
            trajectory_simulated = numerically_integrate(integrator=integrator_train, p_0=p_0, q_0=q_0, model=model, \
                        method=method, T=max_t, dt=dt, volatile=False, device=device, coarsening_factor=coarsening_factor).to(torch.float64)
            error_total = mse(trajectory_simulated[:max_t, :, :], torch.from_numpy(batch[:max_t, :, :]).to(device).to(dtype=torch.float64))
            error_total.backward()
            opt_model.step()
            total_error += error_total.item() * batch_size
        avg_loss_epoch = total_error/n_samples
        loss_record.append(avg_loss_epoch)
    return model, loss_record, test_data, device

# %%
model_euler, loss_euler, test_data, device = train("euler")
model_leapfrog, loss_leapfrog, test_data, device = train("leapfrog")
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
# inside numerically_integrate
# inside numerically_integrate
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model_euler, loss_euler, test_data, device = train("euler")
#       2 model_leapfrog, loss_leapfrog, test_data, device = train("leapfrog")
#
# Cell In[3], line 51, in train(integrator_train)
#      49 p_0 = z_0_batch_device[:, :dim]
#      50 q_0 = z_0_batch_device[:, dim:]
# ---> 51 trajectory_simulated = numerically_integrate(integrator=integrator_train, p_0=p_0, q_0=q_0, model=model, \
#      52             method=method, T=max_t, dt=dt, volatile=False, device=device, coarsening_factor=coarsening_factor).to(torch.float64)
#      53 error_total = mse(trajectory_simulated[:max_t, :, :], torch.from_numpy(batch[:max_t, :, :]).to(device).to(dtype=torch.float64))
#      54 error_total.backward()
#
# File ~/Desktop/research/hamiltonian_lagrangian/symplectic_adjoint_hnn/model.py:330, in numerically_integrate(integrator, p_0, q_0, model, method, T, dt, volatile, device, coarsening_factor)
#     327 print("inside numerically_integrate")
#     329 if (coarsening_factor > 1):
# --> 330     fine_trajectory = numerically_integrate(integrator, p_0, q_0, model, method, T * coarsening_factor, dt / coarsening_factor, volatile, device)
#     331     print("fine_trajectory", fine_trajectory.shape)
#     332     trajectory_simulated = fine_trajectory[np.arange(T) * coarsening_factor, :, :]
#
# File ~/Desktop/research/hamiltonian_lagrangian/symplectic_adjoint_hnn/model.py:339, in numerically_integrate(integrator, p_0, q_0, model, method, T, dt, volatile, device, coarsening_factor)
#     337     trajectory_simulated = leapfrog(p_0, q_0, model, T, dt, volatile=volatile, device=device)
#     338 elif (integrator == 'euler'):
# --> 339     trajectory_simulated = euler(p_0, q_0, model, T, dt, volatile=volatile, device=device)
#     340 elif (integrator == 'predictor_corrector'):
#     341     trajectory_simulated = predictor_corrector(p_0, q_0, model, T, dt, volatile=volatile, device=device)
#
# File ~/Desktop/research/hamiltonian_lagrangian/symplectic_adjoint_hnn/model.py:198, in euler(p_0, q_0, Func, T, dt, volatile, is_Hamilt, device, use_tqdm)
#     196 else:
#     197     trajectories[i, :, :p_0.shape[1]] = p
# --> 198     trajectories[i, :, p_0.shape[1]:] = q
#     200 hamilt = Func(p, q)
#     201 dpdt = -grad(hamilt.sum(), q, create_graph=not volatile)[0]
#
# RuntimeError: The expanded size of the tensor (6) must match the existing size (34) at non-singleton dimension 1.  Target sizes: [32, 6].  Tensor sizes: [32, 34]

# %%
print(loss_euler)
print(loss_leapfrog)
# Out:
# [17.59023900750719, 16.8510027645692, 11.282659469783518, 11.091570132507911, 10.63240066042847, 8.867864868208448, 8.203220070501622, 8.068907638473506, 7.975863926212288, 7.860702405667877, 7.729111330668404, 7.740525798418676, 7.18572584278339, 7.228579185668966, 6.851360499809761, 7.049695893490167, 6.886080069089604, 6.560598307875792, 6.725852615997038, 7.443164660601973, 6.583411798810282, 7.019614820474284, 7.5233861565086, 6.7174957857622, 6.78870795129993, 6.8390824425707475, 6.831364586537505, 6.940987243933296, 6.780136842616066, 6.5720033069078, 6.94685554205917, 6.373656608954162, 6.249732927942161, 6.399873443963861, 6.542725766559841, 6.8279373834777015, 6.510201694921639, 6.8192129030076725, 6.169036098275245, 6.121501620952992, 6.726071430165154, 6.411212849492086, 7.068403537174354, 6.576205166640668, 6.817878059065672, 6.6274981574194705, 6.263604480033666, 6.238201570307981, 6.284252312574997, 6.40111453272319, 6.518142430533203, 6.567772861565846, 6.401200782984624, 6.666628604732624, 6.11829526387236, 6.2630079029376455, 6.261657160289844, 6.045244651985957, 5.7373845739241185, 6.875462428971036, 6.38580968142001, 6.629409052861002, 6.61908390882933, 7.697270365879417, 7.1860841759618275, 7.448452189615009, 6.973006802649348, 6.52940888096226, 6.403802885556
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 predicted_trajectory_euler = predict(test_data, model_euler, 5, "euler", device, 50, 1).cpu().numpy()
#       2 predicted_trajectory_leapfrog = predict(test_data, model_leapfrog, 5, "leapfrog", device, 50, 1).cpu().numpy()
#       3 # test_error_euler = np.linalg.norm(predicted_trajectory_euler - test_data, axis = -1)
#       4 # test_error_leapfrog = np.linalg.norm(predicted_trajectory_leapfrog - test_data, axis = -1)
#
# Cell In[32], line 11, in predict(test_data, model, method, integrator, device, T_test, dt)
#       7 z_0_npy = test_data[0, :, :]
#       9 z_0 = torch.from_numpy(z_0_npy).to(device).to(dtype=torch.float64)
# ---> 11 trajectory_predicted = numerically_integrate(integrator=integrator, p_0=z_0[:, :dim], q_0=z_0[:, dim:], model=model, \
#      12     method=method, T=T_test, dt=dt, volatile=True, device=device, coarsening_factor=1).to(torch.float64)
#      14 return trajectory_predicted
#
# File ~/Desktop/research/hamiltonian_lagrangian/symplectic_adjoint_hnn/model.py:245, in numerically_integrate(integrator, p_0, q_0, model, method, T, dt, volatile, device, coarsening_factor)
#     243     elif (integrator == 'euler'):
#     244         trajectory_simulated = euler(p_0, q_0, model, T, dt, volatile=volatile, device=device)
# --> 245     elif (integrator == 'predictor_corrector'):
#     246         trajectory_simulated = predictor_corrector(p_0, q_0, model, T, dt, volatile=volatile, device=device)
#     247 elif (method == 1):
#
# File ~/Desktop/research/hamiltonian_lagrangian/symplectic_adjoint_hnn/model.py:104, in euler(p_0, q_0, Func, T, dt, volatile, is_Hamilt, device, use_tqdm)
#     102 if volatile:
#     103     trajectories[i, :, :p_0.shape[1]] = p.detach()
# --> 104     trajectories[i, :, p_0.shape[1]:] = q.detach()
#     105 else:
#     106     trajectories[i, :, :p_0.shape[1]] = p
#
# RuntimeError: The expanded size of the tensor (12) must match the existing size (0) at non-singleton dimension 1.  Target sizes: [150, 12].  Tensor sizes: [150, 0]

# %%
print(test_error_euler.mean(axis = 1))
print(test_error_leapfrog.mean(axis = 1))
# Out:
# [ 0.          7.70654976 14.21340825 18.57900277 20.3635383  19.80851855
#  17.95815728 16.54031885 16.8930863  18.53974532 19.96263475 20.11793546
#  18.88113503 17.03045556 15.9508457  16.4227888  17.74380884 18.76508439
#  18.87276174 18.22994281 17.59697494 17.72597444 18.57574053 19.37892006
#  19.40407901 18.46878644 17.09576972 16.32190819 16.8621157  18.24882648
#  19.36986142 19.48582273 18.59240279 17.35820736 16.72558357 17.18064373
#  18.31393255 19.23213231 19.30413439 18.5400264  17.5292088  17.00238596
#  17.28926717 18.12094268 18.86498741 19.05417419 18.70861538 18.22545326
#  18.02726077 18.2181495 ]
# [ 0.          7.70698287 14.21425941 18.58025298 20.36514325 19.81034936
#  17.95986667 16.54128828 16.89295788 18.53868671 19.9608501  20.11554856
#  18.87827566 17.02748002 15.94856693 16.42173983 17.74370656 18.76555404
#  18.87344788 18.23026968 17.59611086 17.72326922 18.57138617 19.3735913
#  19.39828473 18.46279289 17.08987342 16.31703311 16.85971687 18.24913144
#  19.37157331 19.48761931 18.593251   17.35704388 16.72129782 17.17306162
#  18.3037338  19.2203235  19.29158675 18.52753506 17.51789468 16.99358276
#  17.28374558 18.11856986 18.86481637 19.05488759 18.70883789 18.22346403
#  18.02153989 18.20866379]

# %%
plt.plot(range(test_error_euler.shape[0]), test_error_euler.mean(axis = (1)), label = 'euler')
plt.plot(range(test_error_leapfrog.shape[0]), test_error_leapfrog.mean(axis = (1)), label = 'leapfrog')
plt.xlabel('time steps')
plt.ylabel('mean l2 error')
plt.legend()
plt.show()
